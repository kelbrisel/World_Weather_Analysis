# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8576722ac95441abf34e0e3e4fbdf7a9

# %%
# Import the datetime module from the datetime library
from datetime import datetime

# %%
#List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 747

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create an empty list to hold the weather data
city_data=[]
# Print the beginning of the logging
print("Beginning Data Retrieval        ")
print("--------------------------------")

# Create counters
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description" : city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | mayuge
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | leningradskiy
# Processing Record 7 of Set 1 | zhanakorgan
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | umm kaddadah
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | tshela
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | seymour
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | codrington
# Processing Record 17 of Set 1 | faanui
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | plettenberg bay
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | baft
# Processing Record 23 of Set 1 | vienna
# Processing Record 24 of Set 1 | dobryanka
# Processing Record 25 of Set 1 | souillac
# Processing Record 26 of Set 1 | phalaborwa
# Processing Record 27 of Set 1 | kralendijk
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | raudeberg
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | buraydah
# Processing Record 32 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | rio branco
# Processing Record 36 of Set 1 | hami
# Processing Record 37 of Set 1 | fortuna
# Processing Record 38 of Set 1 | poronaysk
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | alibag
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | necochea
# Processing Record 43 of Set 1 | talnakh
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | amuntai
# Processing Record 46 of Set 1 | basoko
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | antofagasta
# Processing Record 50 of Set 1 | puro
# Processing Record 1 of Set 2 | norman wells
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | srednekolymsk
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 2 | mount pleasant
# Processing Record 11 of Set 2 | tabou
# Processing Record 12 of Set 2 | ilulissat
# Processing Record 13 of Set 2 | mirpur khas
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | katsuura
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | westport
# Processing Record 22 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | bonfim
# Processing Record 25 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 2 | mar del plata
# Processing Record 27 of Set 2 | campo grande
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | lompoc
# Processing Record 30 of Set 2 | rawson
# Processing Record 31 of Set 2 | batangafo
# Processing Record 32 of Set 2 | mwinilunga
# Processing Record 33 of Set 2 | butka
# Processing Record 34 of Set 2 | nisia floresta
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | chuy
# Processing Record 37 of Set 2 | xuddur
# Processing Record 38 of Set 2 | mosquera
# Processing Record 39 of Set 2 | nouadhibou
# Processing Record 40 of Set 2 | busselton
# Processing Record 41 of Set 2 | puerto suarez
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | lamu
# Processing Record 44 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 2 | oneonta
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | severo-kurilsk
# Processing Record 48 of Set 2 | ostrovnoy
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | los llanos de aridane
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | devonport
# Processing Record 3 of Set 3 | adrar
# Processing Record 4 of Set 3 | maha sarakham
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | sobolevo
# Processing Record 8 of Set 3 | zalari
# Processing Record 9 of Set 3 | klaksvik
# Processing Record 10 of Set 3 | manggar
# Processing Record 11 of Set 3 | cape coast
# Processing Record 12 of Set 3 | port macquarie
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | aksarka
# Processing Record 15 of Set 3 | baixo guandu
# Processing Record 16 of Set 3 | stillwater
# Processing Record 17 of Set 3 | yenagoa
# Processing Record 18 of Set 3 | yantal
# Processing Record 19 of Set 3 | hamilton
# Processing Record 20 of Set 3 | taltal
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | broome
# Processing Record 23 of Set 3 | nushki
# Processing Record 24 of Set 3 | havelock
# Processing Record 25 of Set 3 | port elizabeth
# Processing Record 26 of Set 3 | north bend
# Processing Record 27 of Set 3 | nurota
# Processing Record 28 of Set 3 | yaguajay
# Processing Record 29 of Set 3 | torbay
# Processing Record 30 of Set 3 | kieta
# Processing Record 31 of Set 3 | belmonte
# Processing Record 32 of Set 3 | liku
# Processing Record 33 of Set 3 | wajir
# Processing Record 34 of Set 3 | simao
# Processing Record 35 of Set 3 | bindi
# Processing Record 36 of Set 3 | alugan
# Processing Record 37 of Set 3 | staryy nadym
# Processing Record 38 of Set 3 | guerrero negro
# Processing Record 39 of Set 3 | elko
# Processing Record 40 of Set 3 | hofn
# Processing Record 41 of Set 3 | helong
# Processing Record 42 of Set 3 | sechura
# Processing Record 43 of Set 3 | cap malheureux
# Processing Record 44 of Set 3 | hue
# Processing Record 45 of Set 3 | port hardy
# Processing Record 46 of Set 3 | lavrentiya
# Processing Record 47 of Set 3 | mbuguni
# Processing Record 48 of Set 3 | avarua
# Processing Record 49 of Set 3 | kyra
# Processing Record 50 of Set 3 | kapaa
# Processing Record 1 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 4 | belyy yar
# Processing Record 3 of Set 4 | bagado
# Processing Record 4 of Set 4 | kruisfontein
# Processing Record 5 of Set 4 | mokhotlong
# Processing Record 6 of Set 4 | zyryanka
# Processing Record 7 of Set 4 | sitka
# Processing Record 8 of Set 4 | hasaki
# Processing Record 9 of Set 4 | vila franca do campo
# Processing Record 10 of Set 4 | kyabe
# Processing Record 11 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 4 | menongue
# Processing Record 13 of Set 4 | zanjan
# Processing Record 14 of Set 4 | lasa
# Processing Record 15 of Set 4 | touros
# Processing Record 16 of Set 4 | hashtrud
# Processing Record 17 of Set 4 | jiangyou
# Processing Record 18 of Set 4 | tiznit
# Processing Record 19 of Set 4 | atambua
# Processing Record 20 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 4 | santa isabel do rio negro
# Processing Record 22 of Set 4 | kotagiri
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | nizwa
# Processing Record 25 of Set 4 | pskov
# Processing Record 26 of Set 4 | ust-uda
# Processing Record 27 of Set 4 | grand gaube
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | ekuvukeni
# Processing Record 30 of Set 4 | fort nelson
# Processing Record 31 of Set 4 | tuktoyaktuk
# Processing Record 32 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 4 | yamada
# Processing Record 34 of Set 4 | road town
# Processing Record 35 of Set 4 | banda aceh
# Processing Record 36 of Set 4 | waingapu
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | saint george
# Processing Record 39 of Set 4 | bengkulu
# Processing Record 40 of Set 4 | shimanovsk
# Processing Record 41 of Set 4 | santa rosa
# Processing Record 42 of Set 4 | enumclaw
# Processing Record 43 of Set 4 | balakhta
# Processing Record 44 of Set 4 | fairlie
# Processing Record 45 of Set 4 | ligayan
# Processing Record 46 of Set 4 | nantucket
# Processing Record 47 of Set 4 | sioux lookout
# Processing Record 48 of Set 4 | kunda
# Processing Record 49 of Set 4 | pangnirtung
# Processing Record 50 of Set 4 | jumla
# Processing Record 1 of Set 5 | kendari
# Processing Record 2 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 3 of Set 5 | yaan
# Processing Record 4 of Set 5 | longyearbyen
# Processing Record 5 of Set 5 | kirakira
# Processing Record 6 of Set 5 | brindisi
# Processing Record 7 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 8 of Set 5 | tsaratanana
# Processing Record 9 of Set 5 | abu kamal
# Processing Record 10 of Set 5 | sola
# Processing Record 11 of Set 5 | hithadhoo
# Processing Record 12 of Set 5 | dingle
# Processing Record 13 of Set 5 | dickinson
# Processing Record 14 of Set 5 | waddan
# Processing Record 15 of Set 5 | salalah
# Processing Record 16 of Set 5 | muros
# Processing Record 17 of Set 5 | myitkyina
# Processing Record 18 of Set 5 | vestmannaeyjar
# Processing Record 19 of Set 5 | yefimovskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | yulara
# Processing Record 21 of Set 5 | barra do corda
# Processing Record 22 of Set 5 | saint anthony
# Processing Record 23 of Set 5 | doha
# Processing Record 24 of Set 5 | camopi
# Processing Record 25 of Set 5 | esperance
# Processing Record 26 of Set 5 | derzhavinsk
# Processing Record 27 of Set 5 | caraguatatuba
# Processing Record 28 of Set 5 | provideniya
# Processing Record 29 of Set 5 | nalut
# Processing Record 30 of Set 5 | luderitz
# Processing Record 31 of Set 5 | morehead
# Processing Record 32 of Set 5 | progreso
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | severnyy
# Processing Record 35 of Set 5 | palmer
# Processing Record 36 of Set 5 | santa cruz cabralia
# Processing Record 37 of Set 5 | olafsvik
# Processing Record 38 of Set 5 | coracora
# Processing Record 39 of Set 5 | carutapera
# Processing Record 40 of Set 5 | yerbogachen
# Processing Record 41 of Set 5 | caravelas
# Processing Record 42 of Set 5 | smithers
# Processing Record 43 of Set 5 | flinders
# Processing Record 44 of Set 5 | gat
# Processing Record 45 of Set 5 | kargasok
# Processing Record 46 of Set 5 | upernavik
# Processing Record 47 of Set 5 | kapit
# Processing Record 48 of Set 5 | potosi
# Processing Record 49 of Set 5 | shreveport
# Processing Record 50 of Set 5 | asau
# Processing Record 1 of Set 6 | alice springs
# Processing Record 2 of Set 6 | betioky
# Processing Record 3 of Set 6 | vao
# Processing Record 4 of Set 6 | willmar
# Processing Record 5 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 6 | havre-saint-pierre
# Processing Record 9 of Set 6 | kuminskiy
# Processing Record 10 of Set 6 | stokmarknes
# Processing Record 11 of Set 6 | chicama
# Processing Record 12 of Set 6 | butaritari
# Processing Record 13 of Set 6 | nome
# Processing Record 14 of Set 6 | iqaluit
# Processing Record 15 of Set 6 | alofi
# Processing Record 16 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 6 | lao cai
# Processing Record 18 of Set 6 | chokurdakh
# Processing Record 19 of Set 6 | byron bay
# Processing Record 20 of Set 6 | fairbanks
# Processing Record 21 of Set 6 | ronne
# Processing Record 22 of Set 6 | kenai
# Processing Record 23 of Set 6 | san quintin
# Processing Record 24 of Set 6 | coihaique
# Processing Record 25 of Set 6 | aklavik
# Processing Record 26 of Set 6 | moose factory
# Processing Record 27 of Set 6 | port-gentil
# Processing Record 28 of Set 6 | ahipara
# Processing Record 29 of Set 6 | narsaq
# Processing Record 30 of Set 6 | okato
# Processing Record 31 of Set 6 | maniitsoq
# Processing Record 32 of Set 6 | puerto montt
# Processing Record 33 of Set 6 | muravlenko
# Processing Record 34 of Set 6 | gigmoto
# Processing Record 35 of Set 6 | gao
# Processing Record 36 of Set 6 | camargo
# Processing Record 37 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 6 | shihezi
# Processing Record 39 of Set 6 | wolmaranstad
# City not found. Skipping...
# Processing Record 40 of Set 6 | lima
# Processing Record 41 of Set 6 | mount gambier
# Processing Record 42 of Set 6 | saskylakh
# Processing Record 43 of Set 6 | vaini
# Processing Record 44 of Set 6 | pestravka
# Processing Record 45 of Set 6 | airai
# Processing Record 46 of Set 6 | verkhnyaya inta
# Processing Record 47 of Set 6 | staraya poltavka
# Processing Record 48 of Set 6 | mahon
# Processing Record 49 of Set 6 | nikolskoye
# Processing Record 50 of Set 6 | wuning
# Processing Record 1 of Set 7 | don sak
# Processing Record 2 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 4 of Set 7 | kirensk
# Processing Record 5 of Set 7 | beisfjord
# Processing Record 6 of Set 7 | yar-sale
# Processing Record 7 of Set 7 | bosaso
# Processing Record 8 of Set 7 | waipawa
# Processing Record 9 of Set 7 | te anau
# Processing Record 10 of Set 7 | sao lourenco do sul
# Processing Record 11 of Set 7 | muroto
# Processing Record 12 of Set 7 | ostersund
# Processing Record 13 of Set 7 | korla
# Processing Record 14 of Set 7 | hovd
# Processing Record 15 of Set 7 | tonshayevo
# Processing Record 16 of Set 7 | pisco
# Processing Record 17 of Set 7 | kysyl-syr
# Processing Record 18 of Set 7 | praya
# Processing Record 19 of Set 7 | puerto madero
# Processing Record 20 of Set 7 | natal
# Processing Record 21 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 22 of Set 7 | akyab
# Processing Record 23 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 7 | bandarbeyla
# Processing Record 25 of Set 7 | honiara
# Processing Record 26 of Set 7 | walker
# Processing Record 27 of Set 7 | lorengau
# Processing Record 28 of Set 7 | kiama
# Processing Record 29 of Set 7 | kapuskasing
# Processing Record 30 of Set 7 | half moon bay
# Processing Record 31 of Set 7 | emerald
# Processing Record 32 of Set 7 | bolshoy kamen
# Processing Record 33 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 7 | sanandaj
# Processing Record 35 of Set 7 | yushu
# Processing Record 36 of Set 7 | biltine
# Processing Record 37 of Set 7 | sheltozero
# Processing Record 38 of Set 7 | sao filipe
# Processing Record 39 of Set 7 | bocaranga
# City not found. Skipping...
# Processing Record 40 of Set 7 | fort saint james
# Processing Record 41 of Set 7 | phanom sarakham
# Processing Record 42 of Set 7 | walvis bay
# Processing Record 43 of Set 7 | kenora
# Processing Record 44 of Set 7 | rio verde de mato grosso
# Processing Record 45 of Set 7 | motril
# Processing Record 46 of Set 7 | plast
# Processing Record 47 of Set 7 | kavieng
# Processing Record 48 of Set 7 | pangody
# Processing Record 49 of Set 7 | alyangula
# Processing Record 50 of Set 7 | sisimiut
# Processing Record 1 of Set 8 | kudahuvadhoo
# Processing Record 2 of Set 8 | estacion coahuila
# Processing Record 3 of Set 8 | abu samrah
# Processing Record 4 of Set 8 | vanderhoof
# Processing Record 5 of Set 8 | komsomolskiy
# Processing Record 6 of Set 8 | karratha
# Processing Record 7 of Set 8 | bhabua
# Processing Record 8 of Set 8 | douglas
# Processing Record 9 of Set 8 | mandalgovi
# Processing Record 10 of Set 8 | rock sound
# Processing Record 11 of Set 8 | port lincoln
# Processing Record 12 of Set 8 | abashiri
# Processing Record 13 of Set 8 | san pedro
# Processing Record 14 of Set 8 | tuatapere
# Processing Record 15 of Set 8 | saldanha
# Processing Record 16 of Set 8 | saint-francois
# Processing Record 17 of Set 8 | neyshabur
# Processing Record 18 of Set 8 | makakilo city
# Processing Record 19 of Set 8 | kasongo
# Processing Record 20 of Set 8 | santa cruz
# Processing Record 21 of Set 8 | zhucheng
# Processing Record 22 of Set 8 | avera
# Processing Record 23 of Set 8 | oranjemund
# Processing Record 24 of Set 8 | san ramon
# Processing Record 25 of Set 8 | okhotsk
# Processing Record 26 of Set 8 | kisangani
# Processing Record 27 of Set 8 | peniche
# Processing Record 28 of Set 8 | san cristobal
# Processing Record 29 of Set 8 | abasha
# Processing Record 30 of Set 8 | lake cowichan
# Processing Record 31 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 8 | lazo
# Processing Record 33 of Set 8 | areia branca
# Processing Record 34 of Set 8 | ola
# Processing Record 35 of Set 8 | general roca
# Processing Record 36 of Set 8 | chimbote
# Processing Record 37 of Set 8 | marsassoum
# Processing Record 38 of Set 8 | berlevag
# Processing Record 39 of Set 8 | kanye
# Processing Record 40 of Set 8 | sur
# Processing Record 41 of Set 8 | la ronge
# Processing Record 42 of Set 8 | kelso
# Processing Record 43 of Set 8 | alice
# Processing Record 44 of Set 8 | pathein
# Processing Record 45 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 46 of Set 8 | saint-pierre
# Processing Record 47 of Set 8 | ambilobe
# Processing Record 48 of Set 8 | meulaboh
# Processing Record 49 of Set 8 | krasnoselkup
# Processing Record 50 of Set 8 | tiksi
# Processing Record 1 of Set 9 | talas
# Processing Record 2 of Set 9 | aykhal
# Processing Record 3 of Set 9 | dawlatabad
# Processing Record 4 of Set 9 | barraute
# Processing Record 5 of Set 9 | roebourne
# Processing Record 6 of Set 9 | mokhsogollokh
# Processing Record 7 of Set 9 | concarneau
# Processing Record 8 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 9 of Set 9 | raton
# Processing Record 10 of Set 9 | barra velha
# Processing Record 11 of Set 9 | etchojoa
# Processing Record 12 of Set 9 | cayenne
# Processing Record 13 of Set 9 | imbituba
# Processing Record 14 of Set 9 | kawalu
# Processing Record 15 of Set 9 | vila velha
# Processing Record 16 of Set 9 | bocas del toro
# Processing Record 17 of Set 9 | laranja da terra
# Processing Record 18 of Set 9 | dunedin
# Processing Record 19 of Set 9 | qaqortoq
# Processing Record 20 of Set 9 | takoradi
# Processing Record 21 of Set 9 | japura
# Processing Record 22 of Set 9 | tarata
# Processing Record 23 of Set 9 | panguipulli
# Processing Record 24 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 9 | do gonbadan
# Processing Record 26 of Set 9 | chara
# Processing Record 27 of Set 9 | grindavik
# Processing Record 28 of Set 9 | zhezkazgan
# Processing Record 29 of Set 9 | martapura
# Processing Record 30 of Set 9 | burkburnett
# Processing Record 31 of Set 9 | namatanai
# Processing Record 32 of Set 9 | vostok
# Processing Record 33 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 34 of Set 9 | uberaba
# Processing Record 35 of Set 9 | tabuk
# Processing Record 36 of Set 9 | kitakyushu
# Processing Record 37 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 9 | greytown
# Processing Record 39 of Set 9 | margate
# Processing Record 40 of Set 9 | maarianhamina
# Processing Record 41 of Set 9 | aksu
# Processing Record 42 of Set 9 | ancud
# Processing Record 43 of Set 9 | richards bay
# Processing Record 44 of Set 9 | darhan
# Processing Record 45 of Set 9 | zlobin
# Processing Record 46 of Set 9 | ratanpur
# Processing Record 47 of Set 9 | anjiang
# Processing Record 48 of Set 9 | oussouye
# Processing Record 49 of Set 9 | raga
# Processing Record 50 of Set 9 | bulungu
# Processing Record 1 of Set 10 | anshun
# Processing Record 2 of Set 10 | nivala
# Processing Record 3 of Set 10 | loja
# Processing Record 4 of Set 10 | auki
# Processing Record 5 of Set 10 | yagodnoye
# Processing Record 6 of Set 10 | bambanglipuro
# Processing Record 7 of Set 10 | verkhnevilyuysk
# Processing Record 8 of Set 10 | victor harbor
# Processing Record 9 of Set 10 | marzuq
# Processing Record 10 of Set 10 | horsham
# Processing Record 11 of Set 10 | nuuk
# Processing Record 12 of Set 10 | miraflores
# Processing Record 13 of Set 10 | pozo colorado
# Processing Record 14 of Set 10 | acapulco
# Processing Record 15 of Set 10 | namibe
# Processing Record 16 of Set 10 | kloulklubed
# Processing Record 17 of Set 10 | balabac
# Processing Record 18 of Set 10 | svetlogorsk
# Processing Record 19 of Set 10 | faya
# Processing Record 20 of Set 10 | qandala
# Processing Record 21 of Set 10 | altay
# Processing Record 22 of Set 10 | salinopolis
# Processing Record 23 of Set 10 | ambon
# Processing Record 24 of Set 10 | iquitos
# Processing Record 25 of Set 10 | beringovskiy
# Processing Record 26 of Set 10 | port hawkesbury
# Processing Record 27 of Set 10 | roald
# Processing Record 28 of Set 10 | san patricio
# Processing Record 29 of Set 10 | brainerd
# Processing Record 30 of Set 10 | great yarmouth
# Processing Record 31 of Set 10 | sangar
# Processing Record 32 of Set 10 | puerto del rosario
# Processing Record 33 of Set 10 | phuket
# Processing Record 34 of Set 10 | yumen
# Processing Record 35 of Set 10 | yinchuan
# Processing Record 36 of Set 10 | dragor
# Processing Record 37 of Set 10 | jieshi
# Processing Record 38 of Set 10 | manokwari
# Processing Record 39 of Set 10 | port augusta
# Processing Record 40 of Set 10 | vila
# Processing Record 41 of Set 10 | sugod
# Processing Record 42 of Set 10 | hoyerswerda
# Processing Record 43 of Set 10 | somerset east
# Processing Record 44 of Set 10 | kirillov
# Processing Record 45 of Set 10 | bodden town
# Processing Record 46 of Set 10 | honningsvag
# Processing Record 47 of Set 10 | bathsheba
# Processing Record 48 of Set 10 | constitucion
# Processing Record 49 of Set 10 | sampit
# Processing Record 50 of Set 10 | opunake
# Processing Record 1 of Set 11 | tezu
# Processing Record 2 of Set 11 | skjervoy
# Processing Record 3 of Set 11 | philadelphia
# Processing Record 4 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 5 of Set 11 | hit
# Processing Record 6 of Set 11 | leshukonskoye
# Processing Record 7 of Set 11 | cockburn town
# Processing Record 8 of Set 11 | boende
# Processing Record 9 of Set 11 | bridgetown
# Processing Record 10 of Set 11 | cedar city
# Processing Record 11 of Set 11 | kalianget
# Processing Record 12 of Set 11 | wembley
# Processing Record 13 of Set 11 | gorontalo
# Processing Record 14 of Set 11 | praxedis guerrero
# Processing Record 15 of Set 11 | pontianak
# Processing Record 16 of Set 11 | bako
# Processing Record 17 of Set 11 | vila do maio
# Processing Record 18 of Set 11 | khani
# Processing Record 19 of Set 11 | russkaya polyana
# Processing Record 20 of Set 11 | lakes entrance
# Processing Record 21 of Set 11 | mindelo
# Processing Record 22 of Set 11 | washougal
# Processing Record 23 of Set 11 | kandrian
# Processing Record 24 of Set 11 | husavik
# Processing Record 25 of Set 11 | ulaangom
# Processing Record 26 of Set 11 | bubaque
# Processing Record 27 of Set 11 | lumeje
# Processing Record 28 of Set 11 | kyrylivka
# Processing Record 29 of Set 11 | mersing
# Processing Record 30 of Set 11 | mecca
# Processing Record 31 of Set 11 | chengde
# Processing Record 32 of Set 11 | kulhudhuffushi
# Processing Record 33 of Set 11 | shingu
# Processing Record 34 of Set 11 | san rafael
# Processing Record 35 of Set 11 | san luis
# Processing Record 36 of Set 11 | sembakung
# Processing Record 37 of Set 11 | sabha
# Processing Record 38 of Set 11 | watertown
# Processing Record 39 of Set 11 | kamenka
# Processing Record 40 of Set 11 | wanaka
# Processing Record 41 of Set 11 | bossangoa
# Processing Record 42 of Set 11 | saint-louis
# Processing Record 43 of Set 11 | rudbar
# Processing Record 44 of Set 11 | moerai
# Processing Record 45 of Set 11 | riyadh
# Processing Record 46 of Set 11 | veselynove
# Processing Record 47 of Set 11 | saint-denis
# Processing Record 48 of Set 11 | contai
# Processing Record 49 of Set 11 | almaznyy
# Processing Record 50 of Set 11 | paamiut
# Processing Record 1 of Set 12 | celina
# Processing Record 2 of Set 12 | morondava
# Processing Record 3 of Set 12 | borba
# Processing Record 4 of Set 12 | kupang
# Processing Record 5 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 6 of Set 12 | trairi
# Processing Record 7 of Set 12 | fort-shevchenko
# Processing Record 8 of Set 12 | bozoum
# Processing Record 9 of Set 12 | stornoway
# Processing Record 10 of Set 12 | shelomi
# Processing Record 11 of Set 12 | ugoofaaru
# Processing Record 12 of Set 12 | beaumont
# Processing Record 13 of Set 12 | palu
# Processing Record 14 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 12 | turayf
# Processing Record 16 of Set 12 | igarka
# Processing Record 17 of Set 12 | acarau
# Processing Record 18 of Set 12 | winchester
# Processing Record 19 of Set 12 | tinskoy
# Processing Record 20 of Set 12 | wyndham
# Processing Record 21 of Set 12 | nago
# Processing Record 22 of Set 12 | casablanca
# Processing Record 23 of Set 12 | pacifica
# Processing Record 24 of Set 12 | high level
# Processing Record 25 of Set 12 | comodoro rivadavia
# Processing Record 26 of Set 12 | kuzhener
# Processing Record 27 of Set 12 | yakeshi
# Processing Record 28 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 29 of Set 12 | mukhanovo
# City not found. Skipping...
# Processing Record 30 of Set 12 | ternate
# Processing Record 31 of Set 12 | sinnamary
# Processing Record 32 of Set 12 | bagdarin
# Processing Record 33 of Set 12 | sibolga
# Processing Record 34 of Set 12 | voznesenye
# Processing Record 35 of Set 12 | castro
# Processing Record 36 of Set 12 | shakawe
# Processing Record 37 of Set 12 | joshimath
# Processing Record 38 of Set 12 | dorado
# Processing Record 39 of Set 12 | inuvik
# Processing Record 40 of Set 12 | kavaratti
# Processing Record 41 of Set 12 | alanya
# Processing Record 42 of Set 12 | kimbe
# Processing Record 43 of Set 12 | otradinskiy
# City not found. Skipping...
# Processing Record 44 of Set 12 | hualmay
# Processing Record 45 of Set 12 | khuzdar
# Processing Record 46 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 12 | tarko-sale
# Processing Record 48 of Set 12 | saint-michel-des-saints
# Processing Record 49 of Set 12 | vidim
# Processing Record 50 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 13 | tineo
# Processing Record 2 of Set 13 | belfast
# Processing Record 3 of Set 13 | ayan
# Processing Record 4 of Set 13 | moctezuma
# Processing Record 5 of Set 13 | vermilion
# Processing Record 6 of Set 13 | porto novo
# Processing Record 7 of Set 13 | neryungri
# Processing Record 8 of Set 13 | itarema
# Processing Record 9 of Set 13 | price
# Processing Record 10 of Set 13 | bograd
# Processing Record 11 of Set 13 | anadyr
# Processing Record 12 of Set 13 | lethem
# Processing Record 13 of Set 13 | camana
# Processing Record 14 of Set 13 | awjilah
# Processing Record 15 of Set 13 | wichita falls
# Processing Record 16 of Set 13 | russell
# Processing Record 17 of Set 13 | kochubey
# Processing Record 18 of Set 13 | zunyi
# Processing Record 19 of Set 13 | jacqueville
# Processing Record 20 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 13 | stepnyak
# Processing Record 22 of Set 13 | lagoa
# Processing Record 23 of Set 13 | sulangan
# Processing Record 24 of Set 13 | udachnyy
# Processing Record 25 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 26 of Set 13 | gombe
# Processing Record 27 of Set 13 | phan thiet
# Processing Record 28 of Set 13 | salinas
# Processing Record 29 of Set 13 | brae
# Processing Record 30 of Set 13 | barra patuca
# Processing Record 31 of Set 13 | san ramon de la nueva oran
# Processing Record 32 of Set 13 | urumqi
# Processing Record 33 of Set 13 | buckeye
# Processing Record 34 of Set 13 | stryn
# Processing Record 35 of Set 13 | manado
# Processing Record 36 of Set 13 | bulawayo
# Processing Record 37 of Set 13 | usinsk
# Processing Record 38 of Set 13 | christchurch
# Processing Record 39 of Set 13 | sintea mare
# Processing Record 40 of Set 13 | kununurra
# Processing Record 41 of Set 13 | winsum
# Processing Record 42 of Set 13 | labuhan
# Processing Record 43 of Set 13 | swabi
# Processing Record 44 of Set 13 | babocsa
# Processing Record 45 of Set 13 | mitu
# Processing Record 46 of Set 13 | maceio
# Processing Record 47 of Set 13 | dicabisagan
# Processing Record 48 of Set 13 | rocha
# Processing Record 49 of Set 13 | deputatskiy
# Processing Record 50 of Set 13 | ponca city
# Processing Record 1 of Set 14 | kinna
# Processing Record 2 of Set 14 | nouakchott
# Processing Record 3 of Set 14 | moyale
# Processing Record 4 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 14 | arman
# Processing Record 6 of Set 14 | vardo
# Processing Record 7 of Set 14 | aasiaat
# Processing Record 8 of Set 14 | vanimo
# Processing Record 9 of Set 14 | arawa
# Processing Record 10 of Set 14 | pekan
# Processing Record 11 of Set 14 | san carlos de bariloche
# Processing Record 12 of Set 14 | thinadhoo
# Processing Record 13 of Set 14 | koboko
# Processing Record 14 of Set 14 | maraa
# Processing Record 15 of Set 14 | gornopravdinsk
# Processing Record 16 of Set 14 | colon
# Processing Record 17 of Set 14 | andenes
# Processing Record 18 of Set 14 | sergeyevka
# Processing Record 19 of Set 14 | miami shores
# Processing Record 20 of Set 14 | egvekinot
# Processing Record 21 of Set 14 | santa vitoria do palmar
# Processing Record 22 of Set 14 | boa vista
# Processing Record 23 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 24 of Set 14 | bara
# Processing Record 25 of Set 14 | burica
# City not found. Skipping...
# Processing Record 26 of Set 14 | kajaani
# Processing Record 27 of Set 14 | wamba
# Processing Record 28 of Set 14 | vestmanna
# Processing Record 29 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 30 of Set 14 | trelew
# Processing Record 31 of Set 14 | belyy gorodok
# Processing Record 32 of Set 14 | dobroye
# Processing Record 33 of Set 14 | beloha
# Processing Record 34 of Set 14 | ulaanbaatar
# Processing Record 35 of Set 14 | saint-joseph
# Processing Record 36 of Set 14 | banjar
# Processing Record 37 of Set 14 | kamaishi
# Processing Record 38 of Set 14 | kankaanpaa
# Processing Record 39 of Set 14 | gawler
# Processing Record 40 of Set 14 | hambantota
# Processing Record 41 of Set 14 | quimper
# Processing Record 42 of Set 14 | portland
# Processing Record 43 of Set 14 | botou
# Processing Record 44 of Set 14 | jiayuguan
# Processing Record 45 of Set 14 | haines junction
# Processing Record 46 of Set 14 | sherghati
# Processing Record 47 of Set 14 | soe
# Processing Record 48 of Set 14 | qasigiannguit
# Processing Record 49 of Set 14 | muisne
# Processing Record 50 of Set 14 | yarada
# Processing Record 1 of Set 15 | mitsamiouli
# Processing Record 2 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 3 of Set 15 | bessonovka
# Processing Record 4 of Set 15 | mildura
# Processing Record 5 of Set 15 | namyslow
# Processing Record 6 of Set 15 | mineral wells
# Processing Record 7 of Set 15 | inhambane
# Processing Record 8 of Set 15 | port hedland
# Processing Record 9 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 15 | chabua
# Processing Record 12 of Set 15 | rudnya
# Processing Record 13 of Set 15 | saint-augustin
# Processing Record 14 of Set 15 | mezen
# Processing Record 15 of Set 15 | sao joao da barra
# Processing Record 16 of Set 15 | sterling
# Processing Record 17 of Set 15 | taoudenni
# Processing Record 18 of Set 15 | khash
# Processing Record 19 of Set 15 | ismailia
# Processing Record 20 of Set 15 | sumbe
# Processing Record 21 of Set 15 | tanakpur
# Processing Record 22 of Set 15 | lata
# Processing Record 23 of Set 15 | kerrobert
# Processing Record 24 of Set 15 | viedma
# Processing Record 25 of Set 15 | boguchany
# Processing Record 26 of Set 15 | kahului
# Processing Record 27 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 28 of Set 15 | whitianga
# Processing Record 29 of Set 15 | tiarei
# Processing Record 30 of Set 15 | olga
# Processing Record 31 of Set 15 | hailar
# Processing Record 32 of Set 15 | mehamn
# Processing Record 33 of Set 15 | usogorsk
# Processing Record 34 of Set 15 | lakhipur
# Processing Record 35 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 36 of Set 15 | moron
# Processing Record 37 of Set 15 | cotonou
# Processing Record 38 of Set 15 | revelstoke
# Processing Record 39 of Set 15 | bougouni
# Processing Record 40 of Set 15 | rio cuarto
# Processing Record 41 of Set 15 | aviles
# Processing Record 42 of Set 15 | bonga
# Processing Record 43 of Set 15 | matara
# Processing Record 44 of Set 15 | basco
# Processing Record 45 of Set 15 | caxito
# Processing Record 46 of Set 15 | sosnovka
# Processing Record 47 of Set 15 | urengoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mataura -46.1927  168.8643     55.99        61          80
# 1         Mayuge   0.4597   33.4803     64.85        88           6
# 2      Mahebourg -20.4081   57.7000     77.00        88          40
# 3    Port Alfred -33.5906   26.8910     61.43        63           2
# 4         Kodiak  57.7900 -152.4072     48.20        61          20
# 5  Leningradskiy  69.3833  178.4167     34.20        83          95
# 6    Zhanakorgan  43.9098   67.2495     62.42        35          26
# 7   Punta Arenas -53.1500  -70.9167     48.20        71           0
# 8   Umm Kaddadah  13.6017   26.6876     72.55         9          17
# 9     Bredasdorp -34.5322   20.0403     46.40        93           3
#
#    Wind Speed Country Current Description
# 0        7.00      NZ       broken clouds
# 1        5.39      UG           clear sky
# 2        4.61      MU    scattered clouds
# 3       19.51      ZA           clear sky
# 4        6.91      US          few clouds
# 5        4.05      RU     overcast clouds
# 6        4.56      KZ    scattered clouds
# 7       19.57      CL           clear sky
# 8       14.50      SD          few clouds
# 9        3.22      ZA           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mataura      NZ -46.1927  168.8643     55.99        61          80
# 1         Mayuge      UG   0.4597   33.4803     64.85        88           6
# 2      Mahebourg      MU -20.4081   57.7000     77.00        88          40
# 3    Port Alfred      ZA -33.5906   26.8910     61.43        63           2
# 4         Kodiak      US  57.7900 -152.4072     48.20        61          20
# 5  Leningradskiy      RU  69.3833  178.4167     34.20        83          95
# 6    Zhanakorgan      KZ  43.9098   67.2495     62.42        35          26
# 7   Punta Arenas      CL -53.1500  -70.9167     48.20        71           0
# 8   Umm Kaddadah      SD  13.6017   26.6876     72.55         9          17
# 9     Bredasdorp      ZA -34.5322   20.0403     46.40        93           3
#
#    Wind Speed Current Description
# 0        7.00       broken clouds
# 1        5.39           clear sky
# 2        4.61    scattered clouds
# 3       19.51           clear sky
# 4        6.91          few clouds
# 5        4.05     overcast clouds
# 6        4.56    scattered clouds
# 7       19.57           clear sky
# 8       14.50          few clouds
# 9        3.22           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the Weather_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
